# %% [markdown]
# # 数据探索与初步实验
#
# 用于探索 A 股行情数据、验证因子计算逻辑。

# %%
import sys

sys.path.insert(0, "..")

import matplotlib.pyplot as plt  # noqa: E402, F401
import numpy as np  # noqa: E402, F401
import pandas as pd  # noqa: E402, F401
